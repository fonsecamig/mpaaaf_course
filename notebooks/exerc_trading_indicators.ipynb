# %% [markdown]
# # Technical Trading Indicators — Student Exercise
#
# **Objective:** Build a neural network that predicts whether the next day's closing price will be **higher or lower** than today's, using technical indicators computed from a panel of 10 ETFs.
#
# **Data:** 10 diversified ETFs (daily OHLCV, 2015–2024), downloaded with `yfinance`:
#
# | Ticker | Name | Category |
# |--------|------|----------|
# | SPY | SPDR S&P 500 ETF | US Large Cap Equity |
# | QQQ | Invesco Nasdaq-100 ETF | US Tech Equity |
# | IWM | iShares Russell 2000 ETF | US Small Cap Equity |
# | EFA | iShares MSCI EAFE ETF | International Developed Equity |
# | EEM | iShares MSCI Emerging Markets ETF | Emerging Market Equity |
# | TLT | iShares 20+ Year Treasury Bond ETF | Long-Term Bonds |
# | GLD | SPDR Gold Shares ETF | Commodities |
# | VNQ | Vanguard Real Estate ETF | Real Estate |
# | XLE | Energy Select Sector SPDR ETF | Sector — Energy |
# | XLF | Financial Select Sector SPDR ETF | Sector — Financials |
#
# ---

# %% [markdown]
# ---
# ## 1 · Download Data
#
# **Q1.** Download daily OHLCV data for all 10 ETFs using `yfinance`. Store each ETF in a dictionary `raw_all` where the key is the ticker string and the value is a DataFrame with columns `Open, High, Low, Close, Volume`.
#
# Print the number of trading days and date range for each ETF.

# %%
raw_all = {}

# YOUR CODE HERE

# %% [markdown]
# **Q2.** Plot the adjusted closing price of all 10 ETFs in a 5×2 grid of subplots. Label each subplot with the ticker.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Q3.** Looking at the price charts, identify:
# - Which ETF shows the strongest upward trend over the full period?
# - Which ETF appears most volatile?
# - Which two ETFs seem most correlated to each other?
#
# *Write your answers here.*

# %% [markdown]
# ---
# ## 2 · Feature Engineering
#
# Implement a function `compute_indicators(raw)` that takes a single-ETF OHLCV DataFrame and returns it augmented with all the technical indicators listed below. Then apply it to each ETF and stack the results into a single panel DataFrame with a `ticker` column.
#
# ### Returns & Volatility
#
# **Q4.** Implement log-returns for $n = 1, 5, 10, 20$ days, realised volatility (rolling std of 1-day log-returns) for $n = 5, 10, 20, 60$ days, the overnight gap, the intraday range, ATR (14), and the Garman-Klass volatility estimator (20).

# %%
def compute_indicators(raw):
    df = raw.copy()
    O, H, L, C, V = df['Open'], df['High'], df['Low'], df['Close'], df['Volume']

    # Helper functions
    def ema(s, span): return s.ewm(span=span, adjust=False).mean()
    def sma(s, n):    return s.rolling(n).mean()
    def rstd(s, n):   return s.rolling(n).std()

    # ── Returns & Volatility ─────────────────────────────────────────────────
    # YOUR CODE HERE


    # ── Trend ────────────────────────────────────────────────────────────────
    # YOUR CODE HERE (Q5)


    # ── Momentum ─────────────────────────────────────────────────────────────
    # YOUR CODE HERE (Q6)


    # ── Volume ───────────────────────────────────────────────────────────────
    # YOUR CODE HERE (Q7)


    # ── Mean-Reversion ───────────────────────────────────────────────────────
    # YOUR CODE HERE (Q8)


    return df

# %% [markdown]
# ### Trend Indicators
#
# **Q5.** Inside `compute_indicators`, implement:
# - SMA crossovers for pairs $(5, 20)$, $(10, 50)$, $(50, 200)$
# - EMA crossovers for pairs $(12, 26)$, $(9, 21)$, $(5, 20)$
# - MACD line, signal line, and histogram (all normalised by Close)
# - ADX (14)
# - Parabolic SAR encoded as $(C - \text{SAR})/C$

# %% [markdown]
# ### Momentum Indicators
#
# **Q6.** Inside `compute_indicators`, implement:
# - ROC for $n = 5, 10, 20, 60$ days
# - RSI (14)
# - Stochastic %K (14) and %D (3)
# - Williams %R (14)
# - CCI (20)

# %% [markdown]
# ### Volume Indicators
#
# **Q7.** Inside `compute_indicators`, implement:
# - Volume log-change
# - Volume ratio (20)
# - OBV normalised by its 20-day rolling mean
# - Rolling VWAP distance: $(C - \text{VWAP}_{20})/C$
# - CMF (20)

# %% [markdown]
# ### Mean-Reversion Indicators
#
# **Q8.** Inside `compute_indicators`, implement:
# - Bollinger Band position (20)
# - Distance from 52-week high and low
# - Z-score of price (20)

# %% [markdown]
# ### Apply to all ETFs

# %%
# Apply compute_indicators to each ETF and stack into a panel DataFrame
# The resulting DataFrame should have a 'ticker' column

# YOUR CODE HERE

# %% [markdown]
# **Q9.** How many total rows does the panel have? How many feature columns? Why are there fewer rows than the sum of all individual ETF lengths?

# %% [markdown]
# *Write your answer here.*

# %% [markdown]
# ---
# ## 3 · Exploration
#
# **Q10.** For SPY, plot the following 15 indicators in a 5×3 grid of subplots:
# `log_ret_1`, `rvol_20`, `overnight_gap`, `intraday_range`, `sma_5_20`, `macd_norm`, `adx_14`, `rsi_14`, `stoch_k`, `cci_20`, `vol_ratio_20`, `cmf_20`, `bb_pos`, `zscore_20`, `dist_52w_high`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Q11.** Plot RSI (14) for all 10 ETFs on the same axes. Add horizontal dashed lines at 70 (overbought) and 30 (oversold). What patterns do you notice across asset classes?

# %%
# YOUR CODE HERE

# %% [markdown]
# *Write your observations here.*

# %% [markdown]
# **Q12.** Compute and plot the feature correlation matrix for SPY. Identify at least two pairs of features that are near-perfectly correlated. Explain why they are redundant.

# %%
# YOUR CODE HERE

# %% [markdown]
# *Write your answer here.*

# %% [markdown]
# ---
# ## 4 · Dataset Preparation
#
# **Q13.** Create a binary target variable `target` for each ETF independently: $y_t = 1$ if $C_{t+1} > C_t$, else $0$. Stack all ETFs into a final dataset, drop rows with NaN, and report:
# - Total number of samples
# - Class balance (% Up vs % Down)
# - Number of samples per ETF

# %%
# YOUR CODE HERE

# %% [markdown]
# **Q14.** Perform a chronological 80/20 train/test split (no random shuffling). Explain in one sentence why shuffling would be inappropriate here.

# %%
# YOUR CODE HERE

# %% [markdown]
# *Write your explanation here.*

# %% [markdown]
# **Q15.** Scale the features using `StandardScaler`. Why must the scaler be fitted **only on the training set** and not on the full dataset?

# %%
# YOUR CODE HERE

# %% [markdown]
# *Write your answer here.*

# %% [markdown]
# ---
# ## 5 · Neural Network
#
# **Q16.** Implement a neural network to predict the binary target after 1 day, using the engineered features and a rolling window of the past price history.

# %% [markdown]
# *Write your observations here.*

# %% [markdown]
# ---
# ## 6 · Evaluation
#
# **Q17.** Compute predictions on the test set and print a full classification report (precision, recall, F1 for both classes) and the ROC-AUC score.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Q18.** Plot the confusion matrix and the ROC curve side by side.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Q19.** Plot the distribution of predicted probabilities separately for true Up and true Down samples. What does this plot reveal about the model's confidence?

# %%
# YOUR CODE HERE

# %% [markdown]
# *Write your observations here.*

# %% [markdown]
# **Q20.** The model's accuracy may be close to 50%. Does that necessarily mean it has learned nothing? Justify your answer using the ROC-AUC score and the probability distribution plot.

# %% [markdown]
# *Write your answer here.*

# %% [markdown]
# ---
# ## 7 · Critical Analysis
#
# Answer the following questions based on your results and understanding of the material.
#
# **Q20.** Explain the concept of **look-ahead bias**. Give one concrete example of how it could accidentally be introduced in this pipeline.

# %% [markdown]
# *Write your answer here.*

# %% [markdown]
# **Q21.** SPY, QQQ, and IWM are all US equity ETFs and are highly correlated. How does including all three affect the training dataset? Would you keep all three or remove some? Justify your choice.

# %% [markdown]
# *Write your answer here.*
